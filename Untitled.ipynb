# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data.csv')

# %%
df.head(10)
# Out:
#            X          Y
# 0  32.502345  31.707006
# 1  53.426804  68.777596
# 2  61.530358  62.562382
# 3  47.475640  71.546632
# 4  59.813208  87.230925
# 5  55.142188  78.211518
# 6  52.211797  79.641973
# 7  39.299567  59.171489
# 8  48.105042  75.331242
# 9  52.550014  71.300880

# %%
plt.plot(df['X'],df['Y'])

# %%
plt.scatter(df['X'],df['Y'])

# %%
from scipy.stats import pearsonr,norm

# %%
pearsonr(df['X'],df['Y'])
# Out:
# (0.7737284999056143, 3.855655523944971e-21)

# %%
from scipy.stats import normaltest

# %%
normaltest(df)
# Out:
# NormaltestResult(statistic=array([2.54647499, 1.75847346]), pvalue=array([0.2799239 , 0.41509962]))

# %%
R=normaltest(df['X'])

# %%
print(R)
# Out:
# NormaltestResult(statistic=2.5464749866768988, pvalue=0.27992390143577295)

# %%
A=normaltest(df['Y'])

# %%
print(A)
# Out:
# NormaltestResult(statistic=1.7584734602519885, pvalue=0.41509962383536747)

# %% [markdown]
# # ACF MODEL

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
plt.show(plot_acf)

# %%
plot_acf(df['X'])

# %%
plot_acf(df["Y"])

# %% [markdown]
# # PACF model

# %%
from statsmodels.graphics.tsaplots import plot_pacf

# %%
plot_pacf(df['X'])

# %%
plot_pacf(df['Y'])

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
X=df['X'].values.reshape(-1,1)

# %%
Y=df['Y'].values.reshape(-1,1)

# %%
train_X, test_X, train_Y, test_Y = train_test_split(X,Y, test_size=0.2,random_state=42)
model= LinearRegression()
model.fit(train_X, train_Y)
preds = model.predict(test_X)
print('MSE : {0}'.format(mean_squared_error(test_Y,preds)))
print('Mean abs error ={0}'.format(mean_absolute_error(test_Y,preds)))
# Out:
# MSE : 153.20927167201995
# Mean abs error =10.079985942340153

# %% [markdown]
# # outlier points
# remove those

# %%
import seaborn as sns

# %%
sns.catplot('Y',kind='boxen',data=df)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
